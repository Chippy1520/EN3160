# %% [markdown]
# # EN3160 Assignment 1
#
# **Intensity Transformations and Neighborhood Filtering**
# Chathuka Elapatha
# 230171E

# %%
from pathlib import Path

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

DATA_DIR = Path('../data')
OUTPUT_DIR = Path('../outputs')
OUTPUT_DIR.mkdir(exist_ok=True)

print(f'OpenCV {cv.__version__}; NumPy {np.__version__}')

# %% [markdown]
# ---
#
# ## Report guide
#
# Replace every bracketed prompt with your own work. State parameter values, keep figures readable, and explain what each result demonstrates.
#
# > **Before exporting:** remove this guide and unused prompts. Keep the final report within the 10-page limit.

# %% [markdown]
# ---
#
# ## 1. Piecewise Intensity Transformation

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the breakpoints you selected and explain your implementation and selection reasoning.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 1 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show the transformation curve and original/transformed images. Interpret the visible changes.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 2. White- and Gray-Matter Accentuation

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the mappings used for white matter and gray matter, then explain your reasoning.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 2 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show both transformation plots and outputs. Compare the emphasized intensity ranges.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 3. Gamma Correction in Lab Color Space

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the gamma value and explain how correction was applied to the L channel.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 3 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show original/corrected images and histograms. Explain the histogram and visual changes.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 4. Vibrance Enhancement in HSV Color Space

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the value of a and explain the saturation-channel operation and parameter choice.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 4 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show the original, enhanced image, and transformation curve. Discuss changes and artifacts.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 5. Histogram Equalization

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[Describe your own histogram-equalization procedure and any implementation choices.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 5 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show images and before/after histograms. Explain the contrast and distribution changes.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 6. Foreground-Only Histogram Equalization

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the thresholded channel and threshold. Explain masking, equalization, and recombination.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 6 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show H/S/V planes, mask, original, and result. Discuss foreground improvement and limitations.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 7. Sobel Filtering

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[Describe the filter2D, direct, and separable implementations and relevant boundary choices.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 7 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show comparable outputs. Discuss numerical/visual agreement and computational differences.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 8. Image Zooming

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the scale factor and explain coordinate mapping for nearest-neighbor and bilinear interpolation.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 8 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Report normalized SSD in a table and show outputs. Compare quality, errors, and limitations.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 9. GrabCut Segmentation and Background Blur

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State the initialization/settings and explain segmentation, blur, and recombination.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 9 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show mask, foreground, background, original, and enhanced image. Explain the dark edge and limitations.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## 10. Bilateral Filtering

# %% [markdown]
# ### Method
#
# **Parameters/settings:** `[write values here]`
#
# **Explanation:** `[State OpenCV/custom parameters and define the chosen quantitative comparison measure.]`

# %% [markdown]
# ### Implementation

# %%
# Write your implementation for Question 10 here

# %% [markdown]
# ### Results and discussion
#
# **Evidence:** `[Show original, Gaussian, OpenCV bilateral, and custom outputs. Compare values, edges, runtime, and limitations.]`
#
# **Your interpretation:** `[write a concise, evidence-based interpretation here]`

# %% [markdown]
# ---
#
# ## References
#
# `[List documentation, external sources, and image sources used.]`
